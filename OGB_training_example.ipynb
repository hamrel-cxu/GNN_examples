# %% [markdown]
# # Description
#
# We train a simple GNN comprising of a user-specified number of GCN layers and hidden dimension. The [ogbn-arxiv odataset](https://ogb.stanford.edu/docs/nodeprop/#ogbn-arxiv) comes from [Open Graph Benchmark](https://ogb.stanford.edu/).
#
# The goal is not to reach the state-of-the-art performance as deep GNN models, but rather illustrate how GNN is trained using the [PyG](https://pytorch-geometric.readthedocs.io/en/latest/) package.

# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-6a69925c-1d2b-7bf8-6d53-39cfaafd42af)

# %%
import os
import torch
os.environ['TORCH'] = torch.__version__
print(torch.__version__)
# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git
# !pip install import_ipynb
# !pip install ogb
# !pip install GPUtil
# Out:
# 1.13.1+cu116
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 17.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 38.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.2/280.2 KB 1.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 517.2/517.2 KB 35.7 MB/s eta 0:00:00
#   Building wheel for torch-geometric (pyproject.toml) ... done
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting import_ipynb
#   Downloading import_ipynb-0.1.4-py3-none-any.whl (4.1 kB)
# Requirement already satisfied: IPython in /usr/local/lib/python3.8/dist-packages (from import_ipynb) (7.9.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.8/dist-packages (from import_ipynb) (5.7.1)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 28.9 MB/s eta 0:00:00
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from IPython->import_ipynb) (2.6.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from IPython->import_ipynb) (4.4.2)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from IPython->import_ipynb) (2.0.10)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from IPython->import_ipynb) (0.2.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from IPython->import_ipynb) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.8/dist-packages (from IPython->import_ipynb) (5.7.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from IPython->import_ipynb) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/dist-packages (from IPython->import_ipynb) (57.4.0)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.8/dist-packages (from nbformat->import_ipynb) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.8/dist-packages (from nbformat->import_ipynb) (4.3.3)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.8/dist-packages (from nbformat->import_ipynb) (5.1.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->IPython->import_ipynb) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->import_ipynb) (0.19.3)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->import_ipynb) (5.10.2)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->import_ipynb) (22.2.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->IPython->import_ipynb) (0.2.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->IPython->import_ipynb) (1.15.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.8/dist-packages (from jupyter-core->nbformat->import_ipynb) (2.6.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->IPython->import_ipynb) (0.7.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->import_ipynb) (3.11.0)
# Installing collected packages: jedi, import_ipynb
# Successfully installed import_ipynb-0.1.4 jedi-0.18.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ogb
#   Downloading ogb-1.3.5-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 KB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.29.0 in /usr/local/lib/python3.8/dist-packages (from ogb) (4.64.1)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.8/dist-packages (from ogb) (1.3.5)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.8/dist-packages (from ogb) (1.0.2)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from ogb) (1.13.1+cu116)
# Requirement already satisfied: urllib3>=1.24.0 in /usr/local/lib/python3.8/dist-packages (from ogb) (1.24.3)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from ogb) (1.15.0)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.8/dist-packages (from ogb) (1.21.6)
# Collecting outdated>=0.2.0
#   Downloading outdated-0.2.2-py2.py3-none-any.whl (7.5 kB)
# Collecting littleutils
#   Downloading littleutils-0.2.2.tar.gz (6.6 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools>=44 in /usr/local/lib/python3.8/dist-packages (from outdated>=0.2.0->ogb) (57.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from outdated>=0.2.0->ogb) (2.25.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.24.0->ogb) (2022.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.24.0->ogb) (2.8.2)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.20.0->ogb) (1.7.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.20.0->ogb) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.20.0->ogb) (3.1.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch>=1.6.0->ogb) (4.4.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->outdated>=0.2.0->ogb) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->outdated>=0.2.0->ogb) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->outdated>=0.2.0->ogb) (4.0.0)
# Building wheels for collected packages: littleutils
#   Building wheel for littleutils (setup.py) ... done
#   Created wheel for littleutils: filename=littleutils-0.2.2-py3-none-any.whl size=7047 sha256=ac4423b9482ee4be5a67c26ab6a8ad82139bd1867592b01b1afb74f345d98a83
#   Stored in directory: /root/.cache/pip/wheels/6a/33/c4/0ef84d7f5568c2823e3d63a6e08988852fb9e4bc822034870a
# Successfully built littleutils
# Installing collected packages: littleutils, outdated, ogb
# Successfully installed littleutils-0.2.2 ogb-1.3.5 outdated-0.2.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting GPUtil
#   Downloading GPUtil-1.4.0.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: GPUtil
#   Building wheel for GPUtil (setup.py) ... done
#   Created wheel for GPUtil: filename=GPUtil-1.4.0-py3-none-any.whl size=7409 sha256=3d883ebd76f4519f2b40ee909ed60a1e7a6b052588b7d8b8dac081d8a8bbb71e
#   Stored in directory: /root/.cache/pip/wheels/ba/03/bb/7a97840eb54479b328672e15a536e49dc60da200fb21564d53
# Successfully built GPUtil
# Installing collected packages: GPUtil
# Successfully installed GPUtil-1.4.0

# %%
from torch_geometric.data import Data
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
import json
import numpy as np
import argparse
import torch
import sys
import importlib as ipb
import pickle
import torch.nn as nn
import torch.nn.functional as F
import torch_geometric.transforms as T
from torch_geometric.nn import GCNConv, SAGEConv, ChebConv
import torch.optim.lr_scheduler as lr_scheduler
from ogb.nodeproppred import PygNodePropPredDataset, Evaluator
import GPUtil
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
class Logger(object):
    def __init__(self, runs, info=None):
        self.info = info
        self.results = [[] for _ in range(runs)]
      
    def pickle(self, key_save):
        f = open(key_save, 'wb')
        pickle.dump(self, f, pickle.HIGHEST_PROTOCOL)
        f.close()

    def unpickle(self, key_save):
        with open(key_save, 'rb') as f:
            return pickle.load(f)

    def add_result(self, run, result):
        assert len(result) == 3
        assert run >= 0 and run < len(self.results)
        self.results[run].append(result)

    def print_statistics(self, run=None):
        if run is not None:
            result = 100 * torch.tensor(self.results[run])
            argmax = result[:, 1].argmax().item()
            print(f'Run {run + 1:02d}:')
            print(f'Highest Train: {result[:, 0].max():.2f}')
            print(f'Highest Valid: {result[:, 1].max():.2f}')
            print(f'Highest Test: {result[:, 2].max():.2f}')
            print(f'  Final Train: {result[argmax, 0]:.2f}')
            print(f'  Final Valid: {result[argmax, 1]:.2f}')
            print(f'   Final Test: {result[argmax, 2]:.2f}')
        else:
            result = 100 * torch.tensor(self.results)

            best_results = []
            for r in result:
                train = r[:, 0].max().item()
                valid = r[:, 1].max().item()
                test = r[:, 2].max().item()
                train2 = r[r[:, 1].argmax(), 0].item()
                test2 = r[r[:, 1].argmax(), 2].item()
                best_results.append((train, valid, test, train2, test2))

            best_result = torch.tensor(best_results)

            print(f'All runs:')
            r = best_result[:, 0]
            print(f'Highest Train: {r.mean():.2f} ± {r.std():.2f}')
            r = best_result[:, 1]
            print(f'Highest Valid: {r.mean():.2f} ± {r.std():.2f}')
            r = best_result[:, 2]
            print(f'Highest Test: {r.mean():.2f} ± {r.std():.2f}')
            r = best_result[:, 3]
            print(f'  Final Train: {r.mean():.2f} ± {r.std():.2f}')
            r = best_result[:, 1]
            print(f'  Final Valid: {r.mean():.2f} ± {r.std():.2f}')
            r = best_result[:, 4]
            print(f'   Final Test: {r.mean():.2f} ± {r.std():.2f}')

def train(model, data, args):
    model.train()
    # No batch
    out = model(data.x, data.edge_index)
    loss = F.nll_loss(out, data.y.squeeze(1))
    loss.backward()
    return loss.item()

def test(model, data, split_idx, evaluator):
    model.eval()
    with torch.no_grad():
        out = model(data.x, data.edge_index)
        y_pred = out.argmax(dim=-1, keepdim=True)
        train_acc = evaluator.eval({
            'y_true': data.y[split_idx['train']],
            'y_pred': y_pred[split_idx['train']],
        })['acc']
        valid_acc = evaluator.eval({
            'y_true': data.y[split_idx['valid']],
            'y_pred': y_pred[split_idx['valid']],
        })['acc']
        test_acc = evaluator.eval({
            'y_true': data.y[split_idx['test']],
            'y_pred': y_pred[split_idx['test']],
        })['acc']
    return train_acc, valid_acc, test_acc

# %%
def slide_idx(data, indices):
    full_mat = data.adj_t.to_scipy().tocsr()
    coo = full_mat[indices][:, indices].tocoo() # This is wrong, because it omits "papers" in the future
    values = coo.data
    sub_indices = np.vstack((coo.row, coo.col))
    i = torch.LongTensor(sub_indices)
    v = torch.FloatTensor(values)
    shape = coo.shape
    sub_idx = torch.sparse.FloatTensor(i, v, torch.Size(shape)).coalesce().indices()
    sub_x = data.x[indices]
    sub_y = data.y[indices]
    return Data(x=sub_x, y=sub_y, edge_index=sub_idx).to(device)

def mem_report():
    if device.type == 'cuda':
        GPUs = GPUtil.getGPUs()
        for i, gpu in enumerate(GPUs):
            print('GPU {:d} ... Mem Free: {:.0f}MB / {:.0f}MB | Utilization {:3.0f}%'.format(
                i, gpu.memoryFree, gpu.memoryTotal, gpu.memoryUtil*100))
    else:
        print("CPU RAM Free: "
              + humanize.naturalsize(psutil.virtual_memory().available))

# %%
class GNN(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, num_layers,
                 dropout, FC=False):
        super(GNN, self).__init__()

        self.convs = torch.nn.ModuleList()
        self.FC = FC
        if self.FC:
            self.convs.append(nn.Linear(in_channels, hidden_channels))
        else:
            # One can change the convolutional operator below to any other layer type that takes in node features and edge indices, such as
            # GCNConv, ChebConv, SAGEConv, etc.
            # self.convs.append(GCNConv(in_channels, hidden_channels, cached=True))
            self.convs.append(ChebConv(in_channels, hidden_channels, K=3))
        self.bns = torch.nn.ModuleList()
        self.bns.append(torch.nn.BatchNorm1d(hidden_channels))
        for _ in range(num_layers - 2):
            if self.FC:
                self.convs.append(nn.Linear(hidden_channels, hidden_channels))
            else:
                self.convs.append(
                    GCNConv(hidden_channels, hidden_channels, cached=True))
            self.bns.append(torch.nn.BatchNorm1d(hidden_channels))
        if self.FC:
            self.convs.append(nn.Linear(hidden_channels, out_channels))
        else:
            self.convs.append(GCNConv(hidden_channels, out_channels, cached=True))
        self.dropout = dropout

    def forward(self, x, edge_index):
        for i, conv in enumerate(self.convs):
            if i > 0:
                x = self.bns[i-1](x)
            if self.FC:
                x = conv(x)
            else:
                x = conv(x, edge_index)
            x = F.relu(x)
            if i == len(self.convs[:-1])-1:
                x = F.dropout(x, p=self.dropout, training=self.training)
        return x.log_softmax(dim=-1)

# %%
example_mod = GNN(10,50,10,3,False)
example_mod
# Out:
# GNN(
#   (convs): ModuleList(
#     (0): ChebConv(10, 50, K=3, normalization=sym)
#     (1): GCNConv(50, 50)
#     (2): GCNConv(50, 10)
#   )
#   (bns): ModuleList(
#     (0): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (1): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )

# %%
lr = 1e-3
optim_name = 'Adam'
hidden_channels = 512
use_SVI = False
FC = False  
change_ratio = False  
ratio_mult = 0.25 if change_ratio else 1
if __name__ == "__main__":  
    result_dict = {'SVI-SGD': [], 'SVI-Adam': [], 'SGD': [], 'Adam': []}
    parser = argparse.ArgumentParser(
        description='OGBN-Arxiv (GNN)')
    parser.add_argument('--log_steps', type=int, default=1)
    parser.add_argument('--num_layers', type=int, default=4)
    parser.add_argument('--dropout', type=float, default=0.25)
    parser.add_argument('--lr', type=float, default=lr)
    parser.add_argument('--momentum', type=float, default=0.95)
    parser.add_argument('--epochs', type=int, default=50)
    parser.add_argument('--batch', type=int, default=1)
    parser.add_argument('--runs', type=int, default=3)
    parser.add_argument('--SVI', type=bool, default=use_SVI)
    parser.add_argument(
        '--optimizer', type=str, default=optim_name)
    parser.add_argument('-f')
    args = parser.parse_args()
    args.FC = FC # If use fully-connected nets instead of GCN layers
    args.change_ratio = change_ratio # If we change ratio of training and test (only used if "ratio_mult" < 1)
    args.ratio_mult = ratio_mult  # Only use X% of training data
    args.lr_drop = 0.98
    args.dec_epoch = 100
    if 1e-3 < args.lr and args.lr <= 1e-2:
        args.lr_drop = 0.96
    # args.hidden_channels = 512 if args.num_layers >= 3 else 1000
    args.hidden_channels = hidden_channels
    print(args)
    dataset = PygNodePropPredDataset(name='ogbn-arxiv',
                                    transform=T.ToSparseTensor())
    data = dataset[0]
    data.adj_t = data.adj_t.to_symmetric()
    data = data.to(device)
    split_idx = dataset.get_idx_split()
    # Split train to train sub and valid
    # Always do because we do not want to "peak" into test features
    train_full = split_idx['train']
    N = len(train_full)
    np.random.seed(1103)
    rand_idx = np.sort(np.random.choice(N, int(N*args.ratio_mult), replace=False))
    split_idx['train'] = split_idx['train'][rand_idx]
    data_train=slide_idx(data, split_idx['train'])
    # Note, cannot sort, because it affects how adjacency matrix acts on data
    all_idx = torch.hstack([val for val in split_idx.values()]) 
    data_full = slide_idx(data, all_idx)
    logger = Logger(args.runs, args)
    results_over_runs = {}
    for run in range(args.runs):
        accu_at_run = []
        args.SVI = use_SVI
        torch.manual_seed(1103 + run)
        model = GNN(data.num_features, args.hidden_channels,
                    dataset.num_classes, args.num_layers,
                    args.dropout, args.FC).to(device)
        evaluator = Evaluator(name='ogbn-arxiv')
        if args.optimizer == 'SGD':
            optimizer = torch.optim.SGD(
                model.parameters(), lr=args.lr, momentum=args.momentum, nesterov=True)
        else:
            optimizer = torch.optim.Adam(
                model.parameters(), lr=args.lr)
        for epoch in range(1, 1 + args.epochs):
            if device.type == 'cuda':
                # Useful to avoid GPU allocation excess
                torch.cuda.empty_cache()
            print(f"LR is {optimizer.param_groups[0]['lr']}")
            optimizer.zero_grad()
            # epoch_stop_SVI = 50
            epoch_stop_SVI = 1000
            if epoch == epoch_stop_SVI + 1 and args.SVI:
                # Reinitialize optimizer to avoid gradient issue
                args.SVI = False
                sdict = model.state_dict()
                print(
                    '############ Pause SVI from now on ############')
                model = GNN(data.num_features, args.hidden_channels,
                    dataset.num_classes, args.num_layers,
                    args.dropout, args.FC).to(device)
                model.load_state_dict(sdict)
                model = model.to(device)
                optimizer = torch.optim.Adam(
                    model.parameters(), lr=args.lr)
            if args.SVI:
                print(f'SVI-{args.optimizer} training')
                loss = train_SVI(model, data_train, args)
            else:
                print(f'{args.optimizer} training')
                loss = train(model, data_train, args)
            optimizer.step()
            mem_report()
            # if epoch > args.dec_epoch:
            #     for p in optimizer.param_groups:
            #         p['lr'] *= args.lr_drop
            print('Testing')
            result = test(model, data_full, split_idx, evaluator)
            mem_report()
            logger.add_result(run, result)
            if epoch % args.log_steps == 0:
                train_acc, valid_acc, test_acc = result
                accu_at_run += [[train_acc, valid_acc, test_acc]]
                print(f'Run: {run + 1:02d}, '
                      f'Epoch: {epoch:02d}, '
                      f'Loss: {loss:.4f}, '
                      f'Train: {100 * train_acc:.2f}%, '
                      f'Valid: {100 * valid_acc:.2f}% '
                      f'Test: {100 * test_acc:.2f}%')
        # Running np.array(accu_at_run) would make it into Epoch-by-3 matrices, but doing so causes .json saving error so I just use the list version
        results_over_runs[f'lr={args.lr}@Run{run+1}'] = accu_at_run
        logger.print_statistics(run)
        # Save results
        key = f'SVI-{optim_name}' if use_SVI else optim_name 
        fc_use = '-FC' if args.FC else ''
        c_ratio = '-change_ratio' if args.change_ratio else ''
        ratio = args.ratio_mult if args.ratio_mult < 1 else ''
        key_save = f'SVI-{optim_name}-{args.num_layers}layers-{args.hidden_channels}nodes-{args.lr}LR{fc_use}{c_ratio}{ratio}_correct_split' if use_SVI else f'{optim_name}-{args.num_layers}layers-{args.hidden_channels}nodes-{args.lr}LR{fc_use}{c_ratio}{ratio}_correct_split'
        logger.pickle(key_save) # Save it to file, but need not now because only one run.
        result_dict[key].append(results_over_runs)
        with open(f"{key_save}.json", "w") as outfile:
            json.dump(result_dict, outfile)
    logger.print_statistics()
# Out:
# Namespace(FC=False, SVI=False, batch=1, change_ratio=False, dec_epoch=100, dropout=0.25, epochs=50, f='/root/.local/share/jupyter/runtime/kernel-91029305-4a23-41cc-9ea4-9c41cdb63470.json', hidden_channels=512, log_steps=1, lr=0.001, lr_drop=0.98, momentum=0.95, num_layers=4, optimizer='Adam', ratio_mult=1, runs=3)
# /usr/local/lib/python3.8/dist-packages/torch_sparse/storage.py:14: UserWarning: `layout` argument unset, using default layout "coo". This may lead to unexpected behaviour.
#   warnings.warn('`layout` argument unset, using default layout '
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 9117MB / 15360MB | Utilization  39%
# Testing
# GPU 0 ... Mem Free: 9117MB / 15360MB | Utilization  39%
# Run: 01, Epoch: 01, Loss: 4.0641, Train: 11.39%, Valid: 11.39% Test: 11.33%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 02, Loss: 3.0059, Train: 16.05%, Valid: 15.93% Test: 15.94%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 03, Loss: 2.3928, Train: 16.05%, Valid: 15.94% Test: 16.02%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 04, Loss: 2.0112, Train: 16.25%, Valid: 16.05% Test: 16.20%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 05, Loss: 1.8324, Train: 16.61%, Valid: 16.59% Test: 16.65%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 06, Loss: 1.6898, Train: 20.82%, Valid: 20.99% Test: 20.76%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 07, Loss: 1.6077, Train: 20.95%, Valid: 21.22% Test: 20.87%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 08, Loss: 1.5489, Train: 20.56%, Valid: 20.70% Test: 20.39%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 09, Loss: 1.4874, Train: 20.16%, Valid: 20.30% Test: 19.98%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 10, Loss: 1.4419, Train: 20.13%, Valid: 20.19% Test: 19.92%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 11, Loss: 1.4133, Train: 21.01%, Valid: 21.04% Test: 20.79%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 12, Loss: 1.3782, Train: 22.57%, Valid: 22.83% Test: 22.45%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 13, Loss: 1.3430, Train: 23.98%, Valid: 24.30% Test: 23.88%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 14, Loss: 1.3157, Train: 24.82%, Valid: 25.16% Test: 24.71%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 15, Loss: 1.2960, Train: 25.61%, Valid: 25.94% Test: 25.56%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 16, Loss: 1.2771, Train: 25.11%, Valid: 25.46% Test: 25.05%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 17, Loss: 1.2540, Train: 24.63%, Valid: 24.80% Test: 24.38%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 18, Loss: 1.2356, Train: 24.94%, Valid: 25.05% Test: 24.63%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 19, Loss: 1.2240, Train: 25.86%, Valid: 25.99% Test: 25.45%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 20, Loss: 1.2086, Train: 27.02%, Valid: 27.15% Test: 26.73%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 21, Loss: 1.1947, Train: 28.08%, Valid: 28.27% Test: 27.79%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 22, Loss: 1.1840, Train: 28.86%, Valid: 29.11% Test: 28.57%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 23, Loss: 1.1717, Train: 29.35%, Valid: 29.64% Test: 29.10%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 24, Loss: 1.1596, Train: 29.81%, Valid: 30.14% Test: 29.55%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 25, Loss: 1.1486, Train: 30.47%, Valid: 30.73% Test: 30.16%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 26, Loss: 1.1378, Train: 31.25%, Valid: 31.66% Test: 30.98%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 27, Loss: 1.1265, Train: 31.95%, Valid: 32.39% Test: 31.74%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 28, Loss: 1.1151, Train: 32.61%, Valid: 33.09% Test: 32.45%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 29, Loss: 1.1085, Train: 33.12%, Valid: 33.62% Test: 33.01%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 30, Loss: 1.0987, Train: 33.46%, Valid: 34.13% Test: 33.45%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 31, Loss: 1.0907, Train: 33.77%, Valid: 34.49% Test: 33.80%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 32, Loss: 1.0831, Train: 34.15%, Valid: 34.95% Test: 34.16%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 33, Loss: 1.0714, Train: 34.54%, Valid: 35.33% Test: 34.51%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 34, Loss: 1.0641, Train: 34.89%, Valid: 35.59% Test: 34.77%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 35, Loss: 1.0569, Train: 35.19%, Valid: 35.90% Test: 35.02%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 36, Loss: 1.0486, Train: 35.59%, Valid: 36.27% Test: 35.37%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 37, Loss: 1.0413, Train: 36.00%, Valid: 36.60% Test: 35.84%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 38, Loss: 1.0317, Train: 36.48%, Valid: 37.07% Test: 36.31%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 39, Loss: 1.0254, Train: 36.86%, Valid: 37.30% Test: 36.66%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 40, Loss: 1.0161, Train: 37.17%, Valid: 37.61% Test: 36.93%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 41, Loss: 1.0112, Train: 37.46%, Valid: 37.85% Test: 37.20%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 42, Loss: 1.0042, Train: 37.75%, Valid: 38.11% Test: 37.50%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 43, Loss: 0.9947, Train: 38.03%, Valid: 38.33% Test: 37.84%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 44, Loss: 0.9896, Train: 38.31%, Valid: 38.66% Test: 38.03%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 45, Loss: 0.9829, Train: 38.47%, Valid: 38.76% Test: 38.21%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 46, Loss: 0.9738, Train: 38.60%, Valid: 38.98% Test: 38.36%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 47, Loss: 0.9678, Train: 38.80%, Valid: 39.25% Test: 38.58%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 48, Loss: 0.9638, Train: 39.06%, Valid: 39.52% Test: 38.87%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 49, Loss: 0.9551, Train: 39.30%, Valid: 39.75% Test: 39.18%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Testing
# GPU 0 ... Mem Free: 8891MB / 15360MB | Utilization  40%
# Run: 01, Epoch: 50, Loss: 0.9502, Train: 39.46%, Valid: 39.91% Test: 39.37%
# Run 01:
# Highest Train: 39.46
# Highest Valid: 39.91
# Highest Test: 39.37
#   Final Train: 39.46
#   Final Valid: 39.91
#    Final Test: 39.37
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 01, Loss: 3.9747, Train: 7.32%, Valid: 7.62% Test: 7.40%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 02, Loss: 3.0174, Train: 16.25%, Valid: 16.19% Test: 16.22%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 03, Loss: 2.4578, Train: 20.85%, Valid: 20.62% Test: 20.71%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 04, Loss: 2.0653, Train: 18.32%, Valid: 17.81% Test: 18.15%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 05, Loss: 1.8723, Train: 16.07%, Valid: 15.70% Test: 15.85%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 06, Loss: 1.7166, Train: 15.17%, Valid: 14.93% Test: 15.03%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 07, Loss: 1.6071, Train: 14.88%, Valid: 14.74% Test: 14.79%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 08, Loss: 1.5505, Train: 15.51%, Valid: 15.32% Test: 15.41%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 09, Loss: 1.4978, Train: 16.68%, Valid: 16.48% Test: 16.48%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 10, Loss: 1.4366, Train: 17.92%, Valid: 17.81% Test: 17.71%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 11, Loss: 1.3920, Train: 19.08%, Valid: 18.96% Test: 18.83%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 12, Loss: 1.3698, Train: 19.75%, Valid: 19.69% Test: 19.51%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 13, Loss: 1.3431, Train: 20.40%, Valid: 20.35% Test: 20.17%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 14, Loss: 1.3175, Train: 21.57%, Valid: 21.54% Test: 21.27%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 15, Loss: 1.2993, Train: 21.79%, Valid: 21.92% Test: 21.50%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 16, Loss: 1.2784, Train: 21.29%, Valid: 21.30% Test: 20.99%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 17, Loss: 1.2559, Train: 20.88%, Valid: 20.81% Test: 20.60%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 18, Loss: 1.2363, Train: 21.25%, Valid: 21.10% Test: 20.91%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 19, Loss: 1.2236, Train: 22.38%, Valid: 22.35% Test: 22.07%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 20, Loss: 1.2101, Train: 24.01%, Valid: 24.03% Test: 23.72%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 21, Loss: 1.1954, Train: 25.30%, Valid: 25.36% Test: 25.02%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 22, Loss: 1.1827, Train: 26.26%, Valid: 26.42% Test: 25.99%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 23, Loss: 1.1734, Train: 26.36%, Valid: 26.46% Test: 26.07%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 24, Loss: 1.1625, Train: 26.34%, Valid: 26.41% Test: 26.00%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 25, Loss: 1.1497, Train: 27.40%, Valid: 27.65% Test: 27.13%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 26, Loss: 1.1389, Train: 28.87%, Valid: 29.15% Test: 28.72%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 27, Loss: 1.1254, Train: 30.24%, Valid: 30.67% Test: 30.10%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 28, Loss: 1.1175, Train: 31.15%, Valid: 31.61% Test: 31.08%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 29, Loss: 1.1089, Train: 31.82%, Valid: 32.16% Test: 31.75%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 30, Loss: 1.0990, Train: 32.26%, Valid: 32.58% Test: 32.22%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 31, Loss: 1.0884, Train: 32.78%, Valid: 33.07% Test: 32.73%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 32, Loss: 1.0793, Train: 33.34%, Valid: 33.63% Test: 33.35%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 33, Loss: 1.0729, Train: 33.93%, Valid: 34.21% Test: 33.89%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 34, Loss: 1.0622, Train: 34.38%, Valid: 34.64% Test: 34.29%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 35, Loss: 1.0553, Train: 34.72%, Valid: 35.00% Test: 34.53%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 36, Loss: 1.0487, Train: 35.03%, Valid: 35.28% Test: 34.86%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 37, Loss: 1.0384, Train: 35.50%, Valid: 35.72% Test: 35.34%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 38, Loss: 1.0322, Train: 36.22%, Valid: 36.30% Test: 36.01%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 39, Loss: 1.0235, Train: 36.82%, Valid: 36.92% Test: 36.58%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 40, Loss: 1.0174, Train: 37.16%, Valid: 37.26% Test: 36.88%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 41, Loss: 1.0110, Train: 37.41%, Valid: 37.58% Test: 37.13%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 42, Loss: 1.0031, Train: 37.57%, Valid: 37.85% Test: 37.38%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 43, Loss: 0.9972, Train: 37.85%, Valid: 38.13% Test: 37.70%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 44, Loss: 0.9917, Train: 38.20%, Valid: 38.41% Test: 37.95%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 45, Loss: 0.9827, Train: 38.43%, Valid: 38.54% Test: 38.13%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 46, Loss: 0.9786, Train: 38.62%, Valid: 38.79% Test: 38.24%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 47, Loss: 0.9723, Train: 38.74%, Valid: 38.99% Test: 38.35%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 48, Loss: 0.9658, Train: 38.90%, Valid: 39.09% Test: 38.46%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 49, Loss: 0.9591, Train: 39.03%, Valid: 39.28% Test: 38.65%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8887MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8885MB / 15360MB | Utilization  41%
# Run: 02, Epoch: 50, Loss: 0.9531, Train: 39.18%, Valid: 39.33% Test: 38.71%
# Run 02:
# Highest Train: 39.18
# Highest Valid: 39.33
# Highest Test: 38.71
#   Final Train: 39.18
#   Final Valid: 39.33
#    Final Test: 38.71
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 01, Loss: 3.9148, Train: 16.57%, Valid: 16.72% Test: 16.61%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 02, Loss: 2.8791, Train: 25.16%, Valid: 25.28% Test: 25.11%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 03, Loss: 2.3079, Train: 22.67%, Valid: 22.55% Test: 22.49%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 04, Loss: 2.0021, Train: 24.65%, Valid: 24.67% Test: 24.45%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 05, Loss: 1.8358, Train: 25.00%, Valid: 25.02% Test: 24.95%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 06, Loss: 1.7088, Train: 25.09%, Valid: 25.15% Test: 24.99%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 07, Loss: 1.6127, Train: 24.95%, Valid: 25.09% Test: 24.89%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 08, Loss: 1.5363, Train: 24.58%, Valid: 24.62% Test: 24.44%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 09, Loss: 1.4783, Train: 24.32%, Valid: 24.41% Test: 23.99%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 10, Loss: 1.4325, Train: 23.85%, Valid: 23.91% Test: 23.59%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 11, Loss: 1.3960, Train: 24.57%, Valid: 24.72% Test: 24.33%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 12, Loss: 1.3648, Train: 25.25%, Valid: 25.50% Test: 25.16%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 13, Loss: 1.3360, Train: 25.40%, Valid: 25.50% Test: 25.23%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 14, Loss: 1.3112, Train: 25.26%, Valid: 25.24% Test: 25.04%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 15, Loss: 1.2897, Train: 25.17%, Valid: 25.23% Test: 24.96%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 16, Loss: 1.2700, Train: 25.15%, Valid: 25.15% Test: 24.93%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 17, Loss: 1.2520, Train: 25.58%, Valid: 25.63% Test: 25.34%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 18, Loss: 1.2326, Train: 26.76%, Valid: 26.93% Test: 26.51%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 19, Loss: 1.2179, Train: 28.32%, Valid: 28.47% Test: 28.08%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 20, Loss: 1.2034, Train: 29.48%, Valid: 29.66% Test: 29.31%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 21, Loss: 1.1928, Train: 29.96%, Valid: 30.17% Test: 29.85%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 22, Loss: 1.1828, Train: 29.96%, Valid: 30.20% Test: 29.87%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 23, Loss: 1.1682, Train: 30.61%, Valid: 30.93% Test: 30.53%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 24, Loss: 1.1569, Train: 30.86%, Valid: 30.99% Test: 30.72%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 25, Loss: 1.1459, Train: 31.63%, Valid: 31.73% Test: 31.48%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 26, Loss: 1.1366, Train: 32.51%, Valid: 32.74% Test: 32.36%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 27, Loss: 1.1268, Train: 33.30%, Valid: 33.57% Test: 33.15%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 28, Loss: 1.1169, Train: 33.82%, Valid: 34.16% Test: 33.64%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 29, Loss: 1.1091, Train: 34.17%, Valid: 34.48% Test: 33.96%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 30, Loss: 1.0987, Train: 34.43%, Valid: 34.80% Test: 34.21%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 31, Loss: 1.0904, Train: 34.82%, Valid: 35.19% Test: 34.59%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 32, Loss: 1.0817, Train: 35.39%, Valid: 35.77% Test: 35.18%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 33, Loss: 1.0715, Train: 35.94%, Valid: 36.38% Test: 35.75%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 34, Loss: 1.0653, Train: 36.39%, Valid: 36.79% Test: 36.15%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 35, Loss: 1.0557, Train: 36.71%, Valid: 37.22% Test: 36.50%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 36, Loss: 1.0484, Train: 37.00%, Valid: 37.48% Test: 36.79%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 37, Loss: 1.0431, Train: 37.17%, Valid: 37.60% Test: 36.94%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 38, Loss: 1.0349, Train: 37.38%, Valid: 37.76% Test: 37.12%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 39, Loss: 1.0260, Train: 37.67%, Valid: 38.01% Test: 37.41%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 40, Loss: 1.0204, Train: 37.98%, Valid: 38.26% Test: 37.71%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 41, Loss: 1.0137, Train: 38.25%, Valid: 38.56% Test: 38.02%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 42, Loss: 1.0058, Train: 38.44%, Valid: 38.75% Test: 38.23%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 43, Loss: 1.0012, Train: 38.52%, Valid: 38.88% Test: 38.35%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 44, Loss: 0.9949, Train: 38.69%, Valid: 39.01% Test: 38.50%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 45, Loss: 0.9880, Train: 38.92%, Valid: 39.24% Test: 38.74%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 46, Loss: 0.9809, Train: 39.16%, Valid: 39.40% Test: 38.96%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 47, Loss: 0.9754, Train: 39.32%, Valid: 39.64% Test: 39.24%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 48, Loss: 0.9681, Train: 39.49%, Valid: 39.81% Test: 39.34%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 49, Loss: 0.9635, Train: 39.63%, Valid: 39.96% Test: 39.46%
# LR is 0.001
# Adam training
# GPU 0 ... Mem Free: 8881MB / 15360MB | Utilization  41%
# Testing
# GPU 0 ... Mem Free: 8879MB / 15360MB | Utilization  41%
# Run: 03, Epoch: 50, Loss: 0.9559, Train: 39.77%, Valid: 40.03% Test: 39.55%
# Run 03:
# Highest Train: 39.77
# Highest Valid: 40.03
# Highest Test: 39.55
#   Final Train: 39.77
#   Final Valid: 40.03
#    Final Test: 39.55
# All runs:
# Highest Train: 39.47 ± 0.29
# Highest Valid: 39.76 ± 0.38
# Highest Test: 39.21 ± 0.45
#   Final Train: 39.47 ± 0.29
#   Final Valid: 39.76 ± 0.38
#    Final Test: 39.21 ± 0.45
